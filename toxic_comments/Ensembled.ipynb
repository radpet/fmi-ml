# %%
import pandas as pd

# %%
simple_subm = pd.read_csv("data/sample_submission.csv")

# %%
tf_subm = pd.read_csv("./ClassicalML/submission_tf_lr.csv")

# %%
tf_subm[:5]
# Out:
#                  id     toxic  severe_toxic   obscene    threat    insult  \
# 0  00001cee341fdb12  0.999927      0.201245  0.999576  0.197092  0.917406
# 1  0000247867823ef7  0.000249      0.001643  0.000098  0.000076  0.005060
# 2  00013b17ad220c46  0.003892      0.002042  0.006129  0.000199  0.008413
# 3  00017563c3f7919a  0.000843      0.001547  0.000490  0.000311  0.001773
# 4  00017695ad8997eb  0.020676      0.004117  0.002206  0.000242  0.007394
#
#    identity_hate
# 0       0.228374
# 1       0.000538
# 2       0.000540
# 3       0.000238
# 4       0.000382

# %%
lstm_subm = pd.read_csv("./NN/submission_lstm.csv")

# %%
lstm_subm[:5]
# Out:
#                  id     toxic  severe_toxic   obscene        threat    insult  \
# 0  00001cee341fdb12  0.993657  1.955702e-01  0.971253  3.007804e-02  0.845401
# 1  0000247867823ef7  0.000080  6.428773e-09  0.000008  3.663769e-07  0.000016
# 2  00013b17ad220c46  0.001006  3.342807e-07  0.000152  1.689992e-05  0.000254
# 3  00017563c3f7919a  0.000158  2.095239e-08  0.000021  8.738931e-07  0.000034
# 4  00017695ad8997eb  0.000526  1.368692e-07  0.000078  6.570151e-06  0.000125
#
#    identity_hate
# 0   9.476215e-02
# 1   8.859330e-07
# 2   2.307044e-05
# 3   1.901973e-06
# 4   1.066018e-05

# %%
ensembled_subm = (tf_subm.drop("id", axis=1) + lstm_subm.drop("id", axis=1) ) / 2
ensembled_subm.index = simple_subm["id"]

# %%
ensembled_subm[:5]
# Out:
#                      toxic  severe_toxic   obscene    threat    insult  \
# id
# 00001cee341fdb12  0.996792      0.198408  0.985414  0.113585  0.881403
# 0000247867823ef7  0.000165      0.000821  0.000053  0.000038  0.002538
# 00013b17ad220c46  0.002449      0.001021  0.003141  0.000108  0.004334
# 00017563c3f7919a  0.000500      0.000774  0.000256  0.000156  0.000903
# 00017695ad8997eb  0.010601      0.002059  0.001142  0.000124  0.003759
#
#                   identity_hate
# id
# 00001cee341fdb12       0.161568
# 0000247867823ef7       0.000270
# 00013b17ad220c46       0.000281
# 00017563c3f7919a       0.000120
# 00017695ad8997eb       0.000196

# %%
ensembled_subm.to_csv("./ensembled_lstm_tf_idf.csv")

# %%
conv_bi_lstm = pd.read_csv("./NN/submission_conv_bi_lstm.csv")

# %%
conv_bi_lstm[:5]
# Out:
#                  id     toxic  severe_toxic   obscene        threat    insult  \
# 0  00001cee341fdb12  0.983098  3.250099e-01  0.894379  6.073291e-02  0.791966
# 1  0000247867823ef7  0.001422  4.309163e-07  0.000118  3.681046e-06  0.000071
# 2  00013b17ad220c46  0.006120  4.953741e-06  0.000566  2.956307e-05  0.000446
# 3  00017563c3f7919a  0.000354  2.004824e-08  0.000023  2.661420e-07  0.000009
# 4  00017695ad8997eb  0.002212  8.819903e-07  0.000189  6.896333e-06  0.000124
#
#    identity_hate
# 0       0.182106
# 1       0.000021
# 2       0.000124
# 3       0.000002
# 4       0.000035

# %%
ensembled_subm = (tf_subm.drop("id", axis=1) + lstm_subm.drop("id", axis=1) + conv_bi_lstm.drop("id", axis=1)) / 3
ensembled_subm.index = simple_subm["id"]

# %%
ensembled_subm[:5]
# Out:
#                      toxic  severe_toxic   obscene    threat    insult  \
# id
# 00001cee341fdb12  0.992227      0.240608  0.955069  0.095968  0.851591
# 0000247867823ef7  0.000584      0.000548  0.000075  0.000027  0.001716
# 00013b17ad220c46  0.003673      0.000682  0.002282  0.000082  0.003038
# 00017563c3f7919a  0.000452      0.000516  0.000178  0.000104  0.000605
# 00017695ad8997eb  0.007804      0.001373  0.000824  0.000085  0.002548
#
#                   identity_hate
# id
# 00001cee341fdb12       0.168414
# 0000247867823ef7       0.000187
# 00013b17ad220c46       0.000229
# 00017563c3f7919a       0.000081
# 00017695ad8997eb       0.000143

# %%
ensembled_subm.to_csv("./ensembled_lstm_tf_idf_conv_bi_lstm.csv")
